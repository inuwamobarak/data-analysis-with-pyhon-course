# %% [markdown]
# ## SQL for Data Analysis

# %%
# Importing Dependencies

import sqlite3
import pandas as pd

# %%
# Connecting to Database

conn = sqlite3.connect(':memory:')

# %%
# Connection Object

c = conn.cursor()

# %%
# Query
c.execute("""CREATE TABLE inventory
        (cat text, cost real, invoice real, vendor text)
        """)

# %%
# Inserting into the data

c.execute("""INSERT INTO inventory
          VALUES('A', 20, 2, 'Abc'),
          ('B', 30, 3, 'Def'),
          ('C', 40, 4, 'Efg'),
          ('D', 70, 1, 'Hij')
          """)

# Commit to the Server
conn.commit()

# %%
# Viewing the table

c.execute("SELECT * FROM inventory")
print(c.fetchall())
# Out:
# [('A', 20.0, 2.0, 'Abc'), ('B', 30.0, 3.0, 'Def'), ('C', 40.0, 4.0, 'Efg'), ('D', 70.0, 1.0, 'Hij')]

# %%
df = pd.read_sql_query("SELECT * FROM inventory", conn)
df.head()
# Out:
#   cat  cost  invoice vendor
# 0   A  20.0      2.0    Abc
# 1   B  30.0      3.0    Def
# 2   C  40.0      4.0    Efg
# 3   D  70.0      1.0    Hij

# %% [markdown]
# ## Converting DF to SQL

# %%
df = pd.read_csv("/content/zomato.csv")
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# 1            No                               Fast Food, Beverages
# 2            No                                    Cafe, Beverages
# 3            No                          Biryani, Mughlai, Chinese
# 4            No  BBQ, Continental, North Indian, Chinese, Bever...
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
df.to_sql('df', conn, if_exists='replace', index=False)
# Out:
# 7105

# %%
pd.read_sql("SELECT * FROM df", conn)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# 1            No                               Fast Food, Beverages
# 2            No                                    Cafe, Beverages
# 3            No                          Biryani, Mughlai, Chinese
# 4            No  BBQ, Continental, North Indian, Chinese, Bever...
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
# WHERE Clause and Comparison Operators

quick_bites = pd.read_sql("""
    SELECT * FROM df WHERE "restaurant type"="Quick Bites" """, conn)
quick_bites.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0             restaurant name restaurant type  \
# 0             0           0                #FeelTheROLL     Quick Bites
# 1             1           1                  #L-81 Cafe     Quick Bites
# 2             8           8                    1000 B.C     Quick Bites
# 3            10          10  11 to 11 Express Biriyanis     Quick Bites
# 4            20          20          1992 Chats - Space     Quick Bites
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.2              49                  300.0          Yes
# 3              3.5              22                  300.0          Yes
# 4              3.7              33                  200.0          Yes
#
#   table booking                     cuisines type  \
# 0            No                         Fast Food
# 1            No              Fast Food, Beverages
# 2            No  Arabian, Sandwich, Rolls, Burger
# 3            No                    Biryani, Kebab
# 4            No                       Street Food
#
#                              area          local address
# 0                       Bellandur              Bellandur
# 1  Byresandra,Tavarekere,Madiwala                    HSR
# 2  Byresandra,Tavarekere,Madiwala  Koramangala 5th Block
# 3                 Electronic City        Electronic City
# 4                    Malleshwaram            Rajajinagar

# %%
# WHERE Clause and Comparison Operators

cheap_restaurant = pd.read_sql("""
    SELECT * FROM df WHERE "avg cost (two people)"<200 """, conn)
cheap_restaurant.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name     restaurant type  \
# 0            53          53       4th Tea Block                Cafe
# 1            55          55  50-50 EATING HOUSE         Quick Bites
# 2            58          58     56 Bhoga Sweets  Takeaway, Delivery
# 3            76          76         99 Pancakes      Dessert Parlor
# 4            94          94  A1 Hot Dum Biryani         Quick Bites
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              4.0              62                  150.0           No
# 1              3.2               4                  100.0           No
# 2              3.6              51                  150.0           No
# 3              4.1              41                  150.0          Yes
# 4              3.2               4                  150.0           No
#
#   table booking          cuisines type          area  local address
# 0            No                   Cafe  Basavanagudi      Jayanagar
# 1            No  South Indian, Biryani  Banashankari   Basavanagudi
# 2            No    Mithai, Street Food           HSR            HSR
# 3            No    Desserts, Ice Cream  Brigade Road  Church Street
# 4            No                Biryani    Whitefield     Whitefield

# %%
# WHERE Clause and Comparison Operators

popular_restaurant = pd.read_sql("""
    SELECT * FROM df WHERE "num of ratings">60 """, conn)
popular_restaurant.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            restaurant name     restaurant type  \
# 0             3           3         '@ Biryani Central       Casual Dining
# 1             6           6                    '@Italy       Casual Dining
# 2            11          11         1131 Bar + Kitchen  Bar, Casual Dining
# 3            12          12  12th Main - Grand Mercure         Fine Dining
# 4            13          13              1441 Pizzeria       Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              2.7             135                  550.0          Yes
# 1              4.1             305                  700.0          Yes
# 2              4.4            2861                 1500.0           No
# 3              4.1             353                 2000.0           No
# 4              4.1             119                  800.0          Yes
#
#   table booking                              cuisines type  \
# 0            No                  Biryani, Mughlai, Chinese
# 1            No                                    Italian
# 2           Yes  Continental, Asian, Italian, North Indian
# 3           Yes                            European, Asian
# 4            No                               Pizza, Salad
#
#                              area          local address
# 0                    Marathahalli           Marathahalli
# 1                    Banashankari     Kumaraswamy Layout
# 2                Old Airport Road            Indiranagar
# 3  Byresandra,Tavarekere,Madiwala  Koramangala 3rd Block
# 4                    Basavanagudi               JP Nagar

# %%
# WHERE Clause and Comparison Operators

popular_restaurant = pd.read_sql("""
    SELECT * FROM df WHERE "num of ratings">=62 """, conn)
popular_restaurant.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0            restaurant name     restaurant type  \
# 0             3           3         '@ Biryani Central       Casual Dining
# 1             6           6                    '@Italy       Casual Dining
# 2            11          11         1131 Bar + Kitchen  Bar, Casual Dining
# 3            12          12  12th Main - Grand Mercure         Fine Dining
# 4            13          13              1441 Pizzeria       Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              2.7             135                  550.0          Yes
# 1              4.1             305                  700.0          Yes
# 2              4.4            2861                 1500.0           No
# 3              4.1             353                 2000.0           No
# 4              4.1             119                  800.0          Yes
#
#   table booking                              cuisines type  \
# 0            No                  Biryani, Mughlai, Chinese
# 1            No                                    Italian
# 2           Yes  Continental, Asian, Italian, North Indian
# 3           Yes                            European, Asian
# 4            No                               Pizza, Salad
#
#                              area          local address
# 0                    Marathahalli           Marathahalli
# 1                    Banashankari     Kumaraswamy Layout
# 2                Old Airport Road            Indiranagar
# 3  Byresandra,Tavarekere,Madiwala  Koramangala 3rd Block
# 4                    Basavanagudi               JP Nagar

# %%
# Logical Operators (AND, OR, NOT)

## AND

df_online_order = pd.read_sql("""SELECt * FROM df
                              WHERE online_order="Yes" AND "table booking"="Yes" """, conn)

df_online_order.shape
# Out:
# (362, 12)

# %%
# Logical Operators (AND, OR, NOT)

## OR

df_online_order = pd.read_sql("""SELECt * FROM df
                              WHERE online_order="Yes" OR "table booking"="Yes" """, conn)

df_online_order.shape
# Out:
# (4109, 12)

# %%
# Logical Operators (AND, OR, NOT)

## NOT

df_online_order = pd.read_sql("""SELECt * FROM df
                              WHERE NOT(online_order="Yes" OR "table booking"="Yes") """, conn)

df_online_order.shape
# Out:
# (2996, 12)

# %%
## NOT

df_online_order = pd.read_sql("""SELECt * FROM df
                              WHERE NOT("num of ratings">2861) """, conn)

df_online_order.shape
# Out:
# (7047, 12)

# %%
# Filtering Operators (IN, NOT, IS NULL, BETWEEN)

## IN

area_df = pd.read_sql("""SELECT * FROM df
                      WHERE area IN ("Marathahalli", "Old Airport Road")
                      """, conn)
area_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name     restaurant type  \
# 0             3           3  '@ Biryani Central       Casual Dining
# 1            11          11  1131 Bar + Kitchen  Bar, Casual Dining
# 2            22          22        1TO3 Kitchen            Delivery
# 3            36          36             3 Leafs       Casual Dining
# 4            80          80             99Foods         Quick Bites
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              2.7             135                  550.0          Yes
# 1              4.4            2861                 1500.0           No
# 2              3.1              11                  800.0           No
# 3              3.7             128                  600.0          Yes
# 4              3.4              32                  400.0           No
#
#   table booking                                      cuisines type  \
# 0            No                          Biryani, Mughlai, Chinese
# 1           Yes          Continental, Asian, Italian, North Indian
# 2            No  North Indian, Chinese, Continental, Italian, S...
# 3            No                North Indian, South Indian, Chinese
# 4            No              Biryani, North Indian, Chinese, Kebab
#
#                area  local address
# 0      Marathahalli   Marathahalli
# 1  Old Airport Road    Indiranagar
# 2      Marathahalli   Marathahalli
# 3      Marathahalli  Kaggadasapura
# 4      Marathahalli   Marathahalli

# %%
# Filtering Operators (IN, NOT, IS NULL, BETWEEN)

## NOT IN

area_df = pd.read_sql("""SELECT * FROM df
                      WHERE area NOT IN ("Marathahalli", "Old Airport Road")
                      """, conn)
area_df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name     restaurant type  \
# 0             0           0    #FeelTheROLL         Quick Bites
# 1             1           1      #L-81 Cafe         Quick Bites
# 2             2           2         #refuel                Cafe
# 3             4           4      '@ The Bbq       Casual Dining
# 4             5           5            '@99  Takeaway, Delivery
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.8              40                  700.0          Yes
# 4              3.4              37                  200.0           No
#
#   table booking                                      cuisines type  \
# 0            No                                          Fast Food
# 1            No                               Fast Food, Beverages
# 2            No                                    Cafe, Beverages
# 3            No  BBQ, Continental, North Indian, Chinese, Bever...
# 4            No            Mughlai, Biryani, Chinese, North Indian
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                       Bellandur          Bellandur
# 4                      Whitefield         Whitefield

# %%
# Filtering Operators (IN, NOT, IS NULL, BETWEEN)

## IS NULL

avg_cost = pd.read_sql("""SELECT * FROM df
                      WHERE "avg cost (two people)" IS NULL
                      """, conn)
avg_cost.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name      restaurant type  \
# 0           125         125       ABC Grand        Casual Dining
# 1           201         201        Al Karim        Casual Dining
# 2           337         337     Anand Vihar          Quick Bites
# 3           362         362   Andhra Spices          Quick Bites
# 4           549         549        Bakers77  Bakery, Quick Bites
#
#    rate (out of 5)  num of ratings avg cost (two people) online_order  \
# 0              3.5              54                  None           No
# 1              3.7              90                  None           No
# 2              2.5              58                  None           No
# 3              3.2               4                  None           No
# 4              3.8              35                  None           No
#
#   table booking                            cuisines type              area  \
# 0            No            Andhra, Chinese, North Indian  Old Airport Road
# 1            No  Mughlai, North Indian, Biryani, Chinese      Kammanahalli
# 2            No                    North Indian, Chinese       Frazer Town
# 3            No            Andhra, Chinese, South Indian        Whitefield
# 4            No                        Bakery, Fast Food       Rajajinagar
#
#         local address
# 0         Indiranagar
# 1        Kalyan Nagar
# 2            RT Nagar
# 3         Brookefield
# 4  Basaveshwara Nagar

# %%
# Filtering Operators (IN, NOT, IS NULL, BETWEEN)

## BETWEEN

avg_cost = pd.read_sql("""SELECT * FROM df
                      WHERE "avg cost (two people)" BETWEEN 400 AND 700
                      """, conn)
avg_cost.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             1           1          #L-81 Cafe     Quick Bites
# 1             2           2             #refuel            Cafe
# 2             3           3  '@ Biryani Central   Casual Dining
# 3             4           4          '@ The Bbq   Casual Dining
# 4             6           6             '@Italy   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.9              48                  400.0          Yes
# 1              3.7              37                  400.0          Yes
# 2              2.7             135                  550.0          Yes
# 3              2.8              40                  700.0          Yes
# 4              4.1             305                  700.0          Yes
#
#   table booking                                      cuisines type  \
# 0            No                               Fast Food, Beverages
# 1            No                                    Cafe, Beverages
# 2            No                          Biryani, Mughlai, Chinese
# 3            No  BBQ, Continental, North Indian, Chinese, Bever...
# 4            No                                            Italian
#
#                              area       local address
# 0  Byresandra,Tavarekere,Madiwala                 HSR
# 1               Bannerghatta Road   Bannerghatta Road
# 2                    Marathahalli        Marathahalli
# 3                       Bellandur           Bellandur
# 4                    Banashankari  Kumaraswamy Layout

# %%
# ORDER BY Clause (For sorting)

avg_cost = pd.read_sql("""SELECT * FROM df
                      ORDER BY "avg cost (two people)"
                      """, conn)

avg_cost.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0 restaurant name      restaurant type  \
# 0           125         125       ABC Grand        Casual Dining
# 1           201         201        Al Karim        Casual Dining
# 2           337         337     Anand Vihar          Quick Bites
# 3           362         362   Andhra Spices          Quick Bites
# 4           549         549        Bakers77  Bakery, Quick Bites
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.5              54                    NaN           No
# 1              3.7              90                    NaN           No
# 2              2.5              58                    NaN           No
# 3              3.2               4                    NaN           No
# 4              3.8              35                    NaN           No
#
#   table booking                            cuisines type              area  \
# 0            No            Andhra, Chinese, North Indian  Old Airport Road
# 1            No  Mughlai, North Indian, Biryani, Chinese      Kammanahalli
# 2            No                    North Indian, Chinese       Frazer Town
# 3            No            Andhra, Chinese, South Indian        Whitefield
# 4            No                        Bakery, Fast Food       Rajajinagar
#
#         local address
# 0         Indiranagar
# 1        Kalyan Nagar
# 2            RT Nagar
# 3         Brookefield
# 4  Basaveshwara Nagar

# %%
# ORDER BY Clause (For sorting)

## DESC

avg_cost = pd.read_sql("""SELECT * FROM df
                      ORDER BY "avg cost (two people)" DESC
                      """, conn)

avg_cost.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                         restaurant name  \
# 0          3561        3561  Le Cirque Signature - The Leela Palace
# 1          5090        5090              Royal Afghan - ITC Windsor
# 2          3761        3761                  Malties - Radisson Blu
# 3          3485        3485              La Brasserie - Le Meridien
# 4           218         218            Alba - JW Marriott Bengaluru
#
#   restaurant type  rate (out of 5)  num of ratings  avg cost (two people)  \
# 0     Fine Dining              4.3             126                 6000.0
# 1     Fine Dining              4.3             413                 5000.0
# 2          Lounge              4.3              53                 4500.0
# 3     Fine Dining              4.1             309                 4100.0
# 4     Fine Dining              4.4             561                 4000.0
#
#   online_order table booking  \
# 0           No           Yes
# 1           No           Yes
# 2           No            No
# 3           No           Yes
# 4           No           Yes
#
#                                        cuisines type           area  \
# 0                                    French, Italian    Indiranagar
# 1                              North Indian, Mughlai   Malleshwaram
# 2                             Continental, Fast Food   Marathahalli
# 3  North Indian, Continental, Japanese, Chinese, ...   Lavelle Road
# 4                                            Italian  Church Street
#
#       local address
# 0  Old Airport Road
# 1       Sankey Road
# 2      Marathahalli
# 3       Sankey Road
# 4      Lavelle Road

# %%
# GROUP BY Clause (For sorting)

avg_cost = pd.read_sql("""SELECT area, "restaurant name", "restaurant type", "avg cost (two people)" FROM df
                      GROUP BY "restaurant type"
                      """, conn)

avg_cost.head(10)
# Out:
#                              area  \
# 0                    New BEL Road
# 1  Byresandra,Tavarekere,Madiwala
# 2                    Brigade Road
# 3                   Sarjapur Road
# 4                        JP Nagar
# 5               Bannerghatta Road
# 6                Old Airport Road
# 7                      Whitefield
# 8                             HSR
# 9                       Jayanagar
#
#                                     restaurant name         restaurant type  \
# 0                                        7th Heaven                  Bakery
# 1                                     Bake The Cake   Bakery, Beverage Shop
# 2  Bengaluru Baking Company - JW Marriott Bengaluru            Bakery, Cafe
# 3                                      Baker's Home  Bakery, Dessert Parlor
# 4                                       Bake Delite     Bakery, Quick Bites
# 5                                    55 Wall Street                     Bar
# 6                                1131 Bar + Kitchen      Bar, Casual Dining
# 7                                               alt             Bar, Lounge
# 8                                        Baar Union                Bar, Pub
# 9                              A Today Thick Shakes           Beverage Shop
#
#    avg cost (two people)
# 0                  300.0
# 1                  250.0
# 2                 1400.0
# 3                  300.0
# 4                  400.0
# 5                 1300.0
# 6                 1500.0
# 7                 1900.0
# 8                  850.0
# 9                  200.0

# %%
avg_cost.shape
# Out:
# (81, 4)

# %%
# LIMIT, OFFSET, and DISTINCT

## LIMIT

limit = pd.read_sql("""SELECT * FROM df
                    LIMIT 10
                    """, conn)

limit
# Out:
#    Unnamed: 0.1  Unnamed: 0                       restaurant name  \
# 0             0           0                          #FeelTheROLL
# 1             1           1                            #L-81 Cafe
# 2             2           2                               #refuel
# 3             3           3                    '@ Biryani Central
# 4             4           4                            '@ The Bbq
# 5             5           5                                  '@99
# 6             6           6                               '@Italy
# 7             7           7                  '@North Parontha Hut
# 8             8           8                              1000 B.C
# 9             9           9  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#       restaurant type  rate (out of 5)  num of ratings  avg cost (two people)  \
# 0         Quick Bites              3.4               7                  200.0
# 1         Quick Bites              3.9              48                  400.0
# 2                Cafe              3.7              37                  400.0
# 3       Casual Dining              2.7             135                  550.0
# 4       Casual Dining              2.8              40                  700.0
# 5  Takeaway, Delivery              3.4              37                  200.0
# 6       Casual Dining              4.1             305                  700.0
# 7  Takeaway, Delivery              2.8              40                  300.0
# 8         Quick Bites              3.2              49                  300.0
# 9       Casual Dining              3.7              41                  450.0
#
#   online_order table booking  \
# 0           No            No
# 1          Yes            No
# 2          Yes            No
# 3          Yes            No
# 4          Yes            No
# 5           No            No
# 6          Yes            No
# 7           No            No
# 8          Yes            No
# 9           No            No
#
#                                        cuisines type  \
# 0                                          Fast Food
# 1                               Fast Food, Beverages
# 2                                    Cafe, Beverages
# 3                          Biryani, Mughlai, Chinese
# 4  BBQ, Continental, North Indian, Chinese, Bever...
# 5            Mughlai, Biryani, Chinese, North Indian
# 6                                            Italian
# 7                                       North Indian
# 8                   Arabian, Sandwich, Rolls, Burger
# 9                              Biryani, North Indian
#
#                              area          local address
# 0                       Bellandur              Bellandur
# 1  Byresandra,Tavarekere,Madiwala                    HSR
# 2               Bannerghatta Road      Bannerghatta Road
# 3                    Marathahalli           Marathahalli
# 4                       Bellandur              Bellandur
# 5                      Whitefield             Whitefield
# 6                    Banashankari     Kumaraswamy Layout
# 7                     Indiranagar       Old Airport Road
# 8  Byresandra,Tavarekere,Madiwala  Koramangala 5th Block
# 9  Byresandra,Tavarekere,Madiwala                    BTM

# %%
# LIMIT, OFFSET, and DISTINCT

## OFFSET

offset = pd.read_sql("""SELECT * FROM df
                    LIMIT 4
                    OFFSET 6
                    """, conn)

offset
# Out:
#    Unnamed: 0.1  Unnamed: 0                       restaurant name  \
# 0             6           6                               '@Italy
# 1             7           7                  '@North Parontha Hut
# 2             8           8                              1000 B.C
# 3             9           9  100ÃÂÃÂÃÂÃÂÃÂÃÂÃÂÃÂ°C
#
#       restaurant type  rate (out of 5)  num of ratings  avg cost (two people)  \
# 0       Casual Dining              4.1             305                  700.0
# 1  Takeaway, Delivery              2.8              40                  300.0
# 2         Quick Bites              3.2              49                  300.0
# 3       Casual Dining              3.7              41                  450.0
#
#   online_order table booking                     cuisines type  \
# 0          Yes            No                           Italian
# 1           No            No                      North Indian
# 2          Yes            No  Arabian, Sandwich, Rolls, Burger
# 3           No            No             Biryani, North Indian
#
#                              area          local address
# 0                    Banashankari     Kumaraswamy Layout
# 1                     Indiranagar       Old Airport Road
# 2  Byresandra,Tavarekere,Madiwala  Koramangala 5th Block
# 3  Byresandra,Tavarekere,Madiwala                    BTM

# %%
# LIMIT, OFFSET, and DISTINCT

## DISTINCT

distinct = pd.read_sql("""SELECT DISTINCT "cuisines type" FROM df
                    """, conn)

distinct
# Out:
#                                           cuisines type
# 0                                             Fast Food
# 1                                  Fast Food, Beverages
# 2                                       Cafe, Beverages
# 3                             Biryani, Mughlai, Chinese
# 4     BBQ, Continental, North Indian, Chinese, Bever...
# ...                                                 ...
# 2170                         Italian, Chinese, Japanese
# 2171                                      Chinese, Naga
# 2172  Italian, Mexican, Mediterranean, North Indian,...
# 2173                 Cafe, Italian, Continental, Burger
# 2174               Turkish, Fast Food, Biryani, Chinese
#
# [2175 rows x 1 columns]

# %%
# Renaming Columns

new_name = pd.read_sql("""SELECT "cuisines type" AS "cuisines_type",
                       "restaurant name" AS "restaurant_name"
                       FROM df
                       LIMIT 6 OFFSET 25
                       """, conn)

new_name
# Out:
#                                  cuisines_type  \
# 0          American, Continental, Steak, Salad
# 1                                  Continental
# 2                           Asian, Continental
# 3                                       Bakery
# 4                                         Cafe
# 5  Continental, North Indian, Italian, Chinese
#
#                              restaurant_name
# 0                               20 Feet High
# 1  21 C - La Marvella Sarovar Premiere Hotel
# 2                    24 Carats - The Capitol
# 3                     24 Hours Cake Delivery
# 4          24 Hours Coffee Drop - La Classic
# 5           24/7 - The Lalit Ashok Bangalore

# %%
pd.set_option('display.max_colwidth', None)
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0     restaurant name restaurant type  \
# 0             0           0        #FeelTheROLL     Quick Bites
# 1             1           1          #L-81 Cafe     Quick Bites
# 2             2           2             #refuel            Cafe
# 3             3           3  '@ Biryani Central   Casual Dining
# 4             4           4          '@ The Bbq   Casual Dining
#
#    rate (out of 5)  num of ratings  avg cost (two people) online_order  \
# 0              3.4               7                  200.0           No
# 1              3.9              48                  400.0          Yes
# 2              3.7              37                  400.0          Yes
# 3              2.7             135                  550.0          Yes
# 4              2.8              40                  700.0          Yes
#
#   table booking                                       cuisines type  \
# 0            No                                           Fast Food
# 1            No                                Fast Food, Beverages
# 2            No                                     Cafe, Beverages
# 3            No                           Biryani, Mughlai, Chinese
# 4            No  BBQ, Continental, North Indian, Chinese, Beverages
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
df = df.drop(['Unnamed: 0.1', 'Unnamed: 0'], axis=1)
df.columns
# Out:
# Index(['restaurant name', 'restaurant type', 'rate (out of 5)',
#        'num of ratings', 'avg cost (two people)', 'online_order',
#        'table booking', 'cuisines type', 'area', 'local address'],
#       dtype='object')

# %%
# Removing #, '@ with nothing
df['restaurant name'] = df['restaurant name'].str.replace('#', '')
df['restaurant name'] = df['restaurant name'].str.replace("'@ ", '')

# %%
df.head()
# Out:
#    restaurant name restaurant type  rate (out of 5)  num of ratings  \
# 0      FeelTheROLL     Quick Bites              3.4               7
# 1        L-81 Cafe     Quick Bites              3.9              48
# 2           refuel            Cafe              3.7              37
# 3  Biryani Central   Casual Dining              2.7             135
# 4          The Bbq   Casual Dining              2.8              40
#
#    avg cost (two people) online_order table booking  \
# 0                  200.0           No            No
# 1                  400.0          Yes            No
# 2                  400.0          Yes            No
# 3                  550.0          Yes            No
# 4                  700.0          Yes            No
#
#                                         cuisines type  \
# 0                                           Fast Food
# 1                                Fast Food, Beverages
# 2                                     Cafe, Beverages
# 3                           Biryani, Mughlai, Chinese
# 4  BBQ, Continental, North Indian, Chinese, Beverages
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
df['restaurant name'][3]  = 'Middle'
# Out:
# <ipython-input-35-34e01ba1c38a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['restaurant name'][3]  = 'Middle'

# %%
df.head()
# Out:
#   restaurant name restaurant type  rate (out of 5)  num of ratings  \
# 0     FeelTheROLL     Quick Bites              3.4               7
# 1       L-81 Cafe     Quick Bites              3.9              48
# 2          refuel            Cafe              3.7              37
# 3          Middle   Casual Dining              2.7             135
# 4         The Bbq   Casual Dining              2.8              40
#
#    avg cost (two people) online_order table booking  \
# 0                  200.0           No            No
# 1                  400.0          Yes            No
# 2                  400.0          Yes            No
# 3                  550.0          Yes            No
# 4                  700.0          Yes            No
#
#                                         cuisines type  \
# 0                                           Fast Food
# 1                                Fast Food, Beverages
# 2                                     Cafe, Beverages
# 3                           Biryani, Mughlai, Chinese
# 4  BBQ, Continental, North Indian, Chinese, Beverages
#
#                              area      local address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
# Renaming Columns with underscore
df = df.rename(columns = {
    'restaurant name': 'restaurant_name',
    'restaurant type': 'restaurant_type',
    'rate (out of 5)': 'rate_out_of_5',
    'num of ratings': 'num_of_ratings',
    'avg cost (two people)': 'avg_cost_two_people',
    'table booking': 'table_booking',
    'cuisines type': 'cuisines type',
    'local address': 'local_address'

})
df.columns
# Out:
# Index(['restaurant_name', 'restaurant_type', 'rate_out_of_5', 'num_of_ratings',
#        'avg_cost_two_people', 'online_order', 'table_booking', 'cuisines type',
#        'area', 'local_address'],
#       dtype='object')

# %% [markdown]
# ## SQL Functions

# %%
# Converting DF to SQL

df.to_sql('zomato', conn, if_exists='replace', index=False)
df = pd.read_sql("SELECT * FROM zomato", conn)
df.head()
# Out:
#   restaurant_name restaurant_type  rate_out_of_5  num_of_ratings  \
# 0     FeelTheROLL     Quick Bites            3.4               7
# 1       L-81 Cafe     Quick Bites            3.9              48
# 2          refuel            Cafe            3.7              37
# 3          Middle   Casual Dining            2.7             135
# 4         The Bbq   Casual Dining            2.8              40
#
#    avg_cost_two_people online_order table_booking  \
# 0                200.0           No            No
# 1                400.0          Yes            No
# 2                400.0          Yes            No
# 3                550.0          Yes            No
# 4                700.0          Yes            No
#
#                                         cuisines type  \
# 0                                           Fast Food
# 1                                Fast Food, Beverages
# 2                                     Cafe, Beverages
# 3                           Biryani, Mughlai, Chinese
# 4  BBQ, Continental, North Indian, Chinese, Beverages
#
#                              area      local_address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
# UPPER (Convert text to Uppercase)

upper = pd.read_sql("""
                    SELECT UPPER(online_order) AS online_order,
                    UPPER(table_booking) AS table_booking
                    FROM zomato
                    LIMIT 4
                    OFFSET 10
                    """, conn)
upper
# Out:
#   online_order table_booking
# 0          YES            NO
# 1           NO           YES
# 2           NO           YES
# 3          YES            NO

# %%
# # Handling database files
# import sqlite3

# # connect to SQLITE databsae
# conn2 = sqlite3.connect('/content/Neisseria.sqlite')

# # Cursor to execute SQL commands
# c = conn2.cursor()

# %%
# # Viewing database tables
# c.execute("SELECT name FROM sqlite_master WHERE type='table' ")
# tables = c.fetchall()

# for table in tables:
#   print(table[0])

# %%
# c.execute("SELECT * FROM EXPERIMENTS")
# print(c.fetchall())

# %%
# import pandas as pd
# df = pd.read_sql_query("SELECT * FROM EXPERIMENTS", conn2)
# df.head()

# %%
# df.head(2)

# %%
# SQL Functions

## Length - Returns the number of strings in a text

length = pd.read_sql("""
                    SELECT Length(restaurant_name) as Restaurant,
                    Length(restaurant_type) as Type
                    FROM zomato WHERE Length(restaurant_name) < 5
                    """, conn)

length.head()
# Out:
#    Restaurant  Type
# 0           4    18
# 1           4    13
# 2           3    18
# 3           4    11
# 4           4    11

# %%
## SUBSTRING (Return a part of a string in a text)

sub = pd.read_sql("""
                    SELECT SUBSTRING(restaurant_name, 2, 6) as Restaurant,
                    restaurant_type as Type
                    FROM zomato WHERE Length(restaurant_name) < 5
                    """, conn)

sub.head()
# Out:
#   Restaurant                Type
# 0        @99  Takeaway, Delivery
# 1        947       Casual Dining
# 2         Q1  Casual Dining, Bar
# 3        0's         Quick Bites
# 4        aha         Quick Bites

# %%
## MIN

min_df = pd.read_sql("""
                    SELECT MIN(num_of_ratings) as Rating,
                    restaurant_name, restaurant_type, area
                    FROM zomato
                    """, conn)

min_df.head()
# Out:
#    Rating restaurant_name restaurant_type          area
# 0       1            Irie   Casual Dining  Kalyan Nagar

# %%
## MAX

max_df = pd.read_sql("""
                    SELECT MAX(num_of_ratings) as Rating,
                    restaurant_name, restaurant_type, area
                    FROM zomato
                    """, conn)

max_df.head()
# Out:
#    Rating              restaurant_name restaurant_type       area
# 0   16345  Byg Brewski Brewing Company    Microbrewery  Bellandur

# %%
## AVG

avg_df = pd.read_sql("""
                    SELECT AVG(num_of_ratings) as Rating,
                    restaurant_name, restaurant_type, area
                    FROM zomato
                    """, conn)

avg_df.head()
# Out:
#        Rating restaurant_name restaurant_type       area
# 0  188.921042     FeelTheROLL     Quick Bites  Bellandur

# %%
## SUM

sum_df = pd.read_sql("""
                    SELECT SUM(num_of_ratings) as Rating, area
                    FROM zomato
                    GROUP BY area
                    """, conn)

sum_df.head()
# Out:
#    Rating               area
# 0   60459       Banashankari
# 1   70353  Bannerghatta Road
# 2   24687       Basavanagudi
# 3   88538          Bellandur
# 4  153342       Brigade Road

# %%
## COUNT

count_df = pd.read_sql("""
                    SELECT COUNT(area)
                    FROM zomato
                    """, conn)

count_df.head()
# Out:
#    COUNT(area)
# 0         7105

# %%
# Boolean Expression

bool_df = pd.read_sql("""
                      SELECT * FROM zomato
                      WHERE(num_of_ratings < 2000 OR num_of_ratings > 10000)
                      """, conn)
bool_df.head()
# Out:
#   restaurant_name restaurant_type  rate_out_of_5  num_of_ratings  \
# 0     FeelTheROLL     Quick Bites            3.4               7
# 1       L-81 Cafe     Quick Bites            3.9              48
# 2          refuel            Cafe            3.7              37
# 3          Middle   Casual Dining            2.7             135
# 4         The Bbq   Casual Dining            2.8              40
#
#    avg_cost_two_people online_order table_booking  \
# 0                200.0           No            No
# 1                400.0          Yes            No
# 2                400.0          Yes            No
# 3                550.0          Yes            No
# 4                700.0          Yes            No
#
#                                         cuisines type  \
# 0                                           Fast Food
# 1                                Fast Food, Beverages
# 2                                     Cafe, Beverages
# 3                           Biryani, Mughlai, Chinese
# 4  BBQ, Continental, North Indian, Chinese, Beverages
#
#                              area      local_address
# 0                       Bellandur          Bellandur
# 1  Byresandra,Tavarekere,Madiwala                HSR
# 2               Bannerghatta Road  Bannerghatta Road
# 3                    Marathahalli       Marathahalli
# 4                       Bellandur          Bellandur

# %%
# Concatenation

concat_df = pd.read_sql("""
                      SELECT area ||' '|| local_address AS area
                      FROM zomato
                      """, conn)
concat_df.head()
# Out:
#                                   area
# 0                  Bellandur Bellandur
# 1   Byresandra,Tavarekere,Madiwala HSR
# 2  Bannerghatta Road Bannerghatta Road
# 3            Marathahalli Marathahalli
# 4                  Bellandur Bellandur

# %%
# CASE Clause

case_df = pd.read_sql("""
                      SELECT area, restaurant_name,	restaurant_type, num_of_ratings,
                        CASE
                          WHEN num_of_ratings > 10000 THEN 'A'
                          WHEN num_of_ratings > 7000 THEN 'B'
                          WHEN num_of_ratings > 5000 THEN 'C'
                          ELSE 'D'
                        END AS 'GRADES'
                      FROM zomato
                      """, conn)
case_df.head()
# Out:
#                              area restaurant_name restaurant_type  \
# 0                       Bellandur     FeelTheROLL     Quick Bites
# 1  Byresandra,Tavarekere,Madiwala       L-81 Cafe     Quick Bites
# 2               Bannerghatta Road          refuel            Cafe
# 3                    Marathahalli          Middle   Casual Dining
# 4                       Bellandur         The Bbq   Casual Dining
#
#    num_of_ratings GRADES
# 0               7      D
# 1              48      D
# 2              37      D
# 3             135      D
# 4              40      D

# %% [markdown]
# ## DATA MANIPULATION

# %%
c.execute("""
          CREATE TABLE
          book_pub(Author, Date, Size, NumberofPages)""")

# %%
# Viewing Existing tables
c.execute("SELECt name FROM sqlite_master WHERE type='table' ")
c.fetchall()
# Out:
# [('inventory',), ('df',), ('zomato',), ('book_pub',)]

# %%
# INSERT Statement
c.execute("""
          INSERT INTO
          book_pub VALUES('Chinua Achebe', '1997', 'Medium', '120') """)
conn.commit()

# %%
c.execute("SELECT * FROM book_pub")
print(c.fetchall())
# Out:
# [('Chinua Achebe', '1997', 'Medium', '120')]

# %%
# UPDATE

c.execute("""
          UPDATE book_pub
          SET Author = 'Prof. Chinua Achebe'
          WHERE date = '1997' """)
conn.commit()

# %%
c.execute("SELECT * FROM book_pub")
print(c.fetchall())
# Out:
# [('Prof. Chinua Achebe', '1997', 'Medium', '120')]

# %%
# DELETE Statement

c.execute("""
          DELETE FROM book_pub
          WHERE date = '1997' """)
conn.commit()

# %%
c.execute("SELECT * FROM book_pub")
print(c.fetchall())
# Out:
# []

# %%
# CREATING VIEWS

## INSERT Statement
c.execute("""
          INSERT INTO
          book_pub VALUES('Chinua Achebe', '1997', 'Medium', '120'),
          ('Zainab Alkali', '2019', 'Medium', '132'),
          ('Cyprain Ekwensi', '2002', 'Large', '450') """)
conn.commit()

# %%
c.execute("""
          CREATE VIEW young_authors4 AS
          SELECT * FROM book_pub
          WHERE Date = '2002' """)
conn.commit()

# %%
c.execute("SELECT * FROM young_authors4")
c.fetchall()
# Out:
# [('Cyprain Ekwensi', '2002', 'Large', '450')]
